# %%
import tensorflow.compat.v1 as tf
import tensorflow_datasets as tfds
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import time
from sklearn.metrics import confusion_matrix
from openpyxl import Workbook

tf.disable_v2_behavior()

# Load and split MNIST dataset
mnist = tfds.load('mnist', split=['train', 'test'], as_supervised=True)
train_data, test_data = mnist

# Preprocessing function
def preprocess(images, labels):
    images = tf.cast(images, tf.float32) / 255.0  # Normalize
    images = tf.reshape(images, [784])  # Flatten
    labels = tf.one_hot(labels, depth=10)  # One-hot encode
    return images, labels

# Hyperparameters
batch_size_list = [1, 10, 100]
epochs_list = [10, 50, 100]

def train_and_evaluate(batch_size, epochs):
    print(f"\nTraining with batch_size={batch_size}, epochs={epochs}")

    # Ensure shuffling for better model learning
    train_dataset = train_data.map(preprocess).shuffle(10000).batch(batch_size)
    test_dataset = test_data.map(preprocess).batch(batch_size)

    X = tf.placeholder(tf.float32, [None, 784])
    Y = tf.placeholder(tf.float32, [None, 10])

    # Model weights and biases
    weights = {
        'h1': tf.Variable(tf.random_normal([784, 128])),
        'h2': tf.Variable(tf.random_normal([128, 64])),
        'out': tf.Variable(tf.random_normal([64, 10]))
    }
    biases = {
        'b1': tf.Variable(tf.random_normal([128])),
        'b2': tf.Variable(tf.random_normal([64])),
        'out': tf.Variable(tf.random_normal([10]))
    }

    # Neural network definition
    def neural_network(x):
        layer1 = tf.nn.relu(tf.add(tf.matmul(x, weights['h1']), biases['b1']))
        layer2 = tf.nn.relu(tf.add(tf.matmul(layer1, weights['h2']), biases['b2']))
        return tf.add(tf.matmul(layer2, weights['out']), biases['out'])

    logits = neural_network(X)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=Y))
    optimizer = tf.train.AdamOptimizer(learning_rate=0.01).minimize(loss)

    predictions = tf.nn.softmax(logits)
    correct_pred = tf.equal(tf.argmax(predictions, 1), tf.argmax(Y, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

    loss_curve, acc_curve, val_acc_curve = [], [], []
    start_time = time.time()

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())

        for epoch in range(epochs):
            avg_loss = 0
            total_batches = 0
            correct_preds = 0
            total_samples = 0

            iterator = tf.compat.v1.data.make_one_shot_iterator(train_dataset)
            next_batch = iterator.get_next()

            while True:
                try:
                    batch_x, batch_y = sess.run(next_batch)
                    _, c, preds = sess.run([optimizer, loss, predictions], feed_dict={X: batch_x, Y: batch_y})

                    avg_loss += c
                    total_batches += 1

                    correct_preds += np.sum(np.argmax(preds, axis=1) == np.argmax(batch_y, axis=1))
                    total_samples += batch_x.shape[0]

                except tf.errors.OutOfRangeError:
                    break  

            avg_loss /= total_batches
            train_acc = correct_preds / total_samples  # Compute train accuracy over full dataset
            val_acc = sess.run(accuracy, feed_dict={X: batch_x, Y: batch_y})  # Last batch validation accuracy

            loss_curve.append(avg_loss)
            acc_curve.append(train_acc)  # Append proper train accuracy
            val_acc_curve.append(val_acc)

            print(f"Epoch {epoch+1}, Loss: {avg_loss:.4f}, Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}")

        end_time = time.time()
        execution_time = end_time - start_time

        # Testing
        test_acc = []
        y_true, y_pred = [], []
        iterator = tf.compat.v1.data.make_one_shot_iterator(test_dataset)
        next_batch = iterator.get_next()

        while True:
            try:
                batch_x, batch_y = sess.run(next_batch)
                acc, preds = sess.run([accuracy, predictions], feed_dict={X: batch_x, Y: batch_y})
                test_acc.append(acc)
                y_pred.extend(np.argmax(preds, axis=1))
                y_true.extend(np.argmax(batch_y, axis=1))
            except tf.errors.OutOfRangeError:
                break

        final_test_acc = np.mean(test_acc)
        print(f"Test Accuracy: {final_test_acc:.4f}")

        # Confusion Matrix
        conf_matrix = confusion_matrix(y_true, y_pred)
        plt.figure(figsize=(8, 6))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title(f"Confusion Matrix (Batch={batch_size}, Epochs={epochs})")
        cm_filename = f"confusion_matrix_batch{batch_size}_epochs{epochs}.png"
        plt.savefig(cm_filename)
        plt.close()

        # Plot Loss and Accuracy Curves
        plt.figure(figsize=(12, 4))

        plt.subplot(1, 2, 1)
        plt.plot(loss_curve, label='Train Loss', linestyle='-', color='blue')
        plt.xlabel("Epochs")
        plt.ylabel("Loss")
        plt.legend()
        plt.title("Loss Curve")

        plt.subplot(1, 2, 2)
        plt.plot(acc_curve, label='Train Accuracy', linestyle='--', color='blue')
        plt.plot(val_acc_curve, label='Validation Accuracy', linestyle='-', color='red')
        plt.xlabel("Epochs")
        plt.ylabel("Accuracy")
        plt.legend()
        plt.title("Accuracy Curve")

        curve_filename = f"curves_batch{batch_size}_epochs{epochs}.png"
        plt.savefig(curve_filename)
        plt.close()

    return batch_size, epochs, execution_time, final_test_acc, cm_filename, curve_filename

# Training for different batch sizes and epochs
results = []
for batch_size in batch_size_list:
    for epochs in epochs_list:
        res = train_and_evaluate(batch_size, epochs)
        results.append(res)

# Save results to Excel
df = pd.DataFrame(results, columns=['Batch Size', 'Epochs', 'Execution Time (s)', 'Test Accuracy', 'Confusion Matrix Image', 'Loss/Accuracy Curves'])
df.to_excel("training_results.xlsx", index=False) 

print("\n All Results Saved in training_results.xlsx")
# Out:
# Training with batch_size=1, epochs=10
# Epoch 1, Loss: 3.3842, Train Acc: 0.1202, Val Acc: 0.0000
# Epoch 2, Loss: 2.3108, Train Acc: 0.1026, Val Acc: 0.0000
# Epoch 3, Loss: 2.3084, Train Acc: 0.1032, Val Acc: 0.0000
# Epoch 4, Loss: 2.3089, Train Acc: 0.1045, Val Acc: 0.0000
# Epoch 5, Loss: 2.3088, Train Acc: 0.1039, Val Acc: 0.0000
# Epoch 6, Loss: 2.3090, Train Acc: 0.1041, Val Acc: 0.0000
# Epoch 7, Loss: 2.3091, Train Acc: 0.1022, Val Acc: 0.0000
# Epoch 8, Loss: 2.3085, Train Acc: 0.1037, Val Acc: 0.0000
# Epoch 9, Loss: 2.3084, Train Acc: 0.1039, Val Acc: 1.0000
# Epoch 10, Loss: 2.3089, Train Acc: 0.1033, Val Acc: 0.0000
# Test Accuracy: 0.1135
#
# Training with batch_size=1, epochs=50
# Epoch 1, Loss: 3.1601, Train Acc: 0.1206, Val Acc: 0.0000
# Epoch 2, Loss: 2.3090, Train Acc: 0.1033, Val Acc: 0.0000
# Epoch 3, Loss: 2.3086, Train Acc: 0.1042, Val Acc: 0.0000
# Epoch 4, Loss: 2.3088, Train Acc: 0.1037, Val Acc: 0.0000
# Epoch 5, Loss: 2.3086, Train Acc: 0.1046, Val Acc: 0.0000
# Epoch 6, Loss: 2.3089, Train Acc: 0.1025, Val Acc: 0.0000
# Epoch 7, Loss: 2.3085, Train Acc: 0.1052, Val Acc: 0.0000
# Epoch 8, Loss: 2.3088, Train Acc: 0.1059, Val Acc: 1.0000
# Epoch 9, Loss: 2.3090, Train Acc: 0.1038, Val Acc: 0.0000
# Epoch 10, Loss: 2.3087, Train Acc: 0.1052, Val Acc: 1.0000
# Epoch 11, Loss: 2.3089, Train Acc: 0.1027, Val Acc: 1.0000
# Epoch 12, Loss: 2.3088, Train Acc: 0.1031, Val Acc: 0.0000
# Epoch 13, Loss: 2.3090, Train Acc: 0.1052, Val Acc: 0.0000
# Epoch 14, Loss: 2.3088, Train Acc: 0.1052, Val Acc: 0.0000
# Epoch 15, Loss: 2.3088, Train Acc: 0.1035, Val Acc: 0.0000
# Epoch 16, Loss: 2.3090, Train Acc: 0.1022, Val Acc: 0.0000
# Epoch 17, Loss: 2.3084, Train Acc: 0.1049, Val Acc: 1.0000
# Epoch 18, Loss: 2.3088, Train Acc: 0.1023, Val Acc: 0.0000
# Epoch 19, Loss: 2.3086, Train Acc: 0.1054, Val Acc: 0.0000
# Epoch 20, Loss: 2.3089, Train Acc: 0.1052, Val Acc: 0.0000
# Epoch 21, Loss: 2.3088, Train Acc: 0.1039, Val Acc: 1.0000
# Epoch 22, Loss: 2.3089, Train Acc: 0.1041, Val Acc: 0.0000
# Epoch 23, Loss: 2.3087, Train Acc: 0.1031, Val Acc: 0.0000
# Epoch 24, Loss: 2.3090, Train Acc: 0.1040, Val Acc: 0.0000
# Epoch 25, Loss: 2.3091, Train Acc: 0.1043, Val Acc: 0.0000
# Epoch 26, Loss: 2.3084, Train Acc: 0.1063, Val Acc: 0.0000
# Epoch 27, Loss: 2.3091, Train Acc: 0.1037, Val Acc: 0.0000
# Epoch 28, Loss: 2.3086, Train Acc: 0.1052, Val Acc: 0.0000
# Epoch 29, Loss: 2.3086, Train Acc: 0.1037, Val Acc: 1.0000
# Epoch 30, Loss: 2.3085, Train Acc: 0.1049, Val Acc: 0.0000
# Epoch 31, Loss: 2.3089, Train Acc: 0.1026, Val Acc: 0.0000
# Epoch 32, Loss: 2.3091, Train Acc: 0.1023, Val Acc: 0.0000
# Epoch 33, Loss: 2.3084, Train Acc: 0.1042, Val Acc: 0.0000
# Epoch 34, Loss: 2.3086, Train Acc: 0.1027, Val Acc: 0.0000
# Epoch 35, Loss: 2.3093, Train Acc: 0.1036, Val Acc: 0.0000
# Epoch 36, Loss: 2.3088, Train Acc: 0.1034, Val Acc: 0.0000
# Epoch 37, Loss: 2.3086, Train Acc: 0.1029, Val Acc: 0.0000
# Epoch 38, Loss: 2.3088, Train Acc: 0.1036, Val Acc: 0.0000
# Epoch 39, Loss: 2.3087, Train Acc: 0.1050, Val Acc: 1.0000
# Epoch 40, Loss: 2.3087, Train Acc: 0.1058, Val Acc: 1.0000
# Epoch 41, Loss: 2.3087, Train Acc: 0.1038, Val Acc: 0.0000
# Epoch 42, Loss: 2.3089, Train Acc: 0.1040, Val Acc: 0.0000
# Epoch 43, Loss: 2.3086, Train Acc: 0.1045, Val Acc: 0.0000
# Epoch 44, Loss: 2.3090, Train Acc: 0.1030, Val Acc: 0.0000
# Epoch 45, Loss: 2.3086, Train Acc: 0.1007, Val Acc: 0.0000
# Epoch 46, Loss: 2.3091, Train Acc: 0.1027, Val Acc: 0.0000
# Epoch 47, Loss: 2.3087, Train Acc: 0.1027, Val Acc: 0.0000
# Epoch 48, Loss: 2.3091, Train Acc: 0.1022, Val Acc: 0.0000
# Epoch 49, Loss: 2.3089, Train Acc: 0.1036, Val Acc: 0.0000
# Epoch 50, Loss: 2.3082, Train Acc: 0.1054, Val Acc: 1.0000
# Test Accuracy: 0.0982
#
# Training with batch_size=1, epochs=100
# Epoch 1, Loss: 3.2727, Train Acc: 0.1194, Val Acc: 0.0000
# Epoch 2, Loss: 2.3170, Train Acc: 0.1056, Val Acc: 0.0000
# Epoch 3, Loss: 2.3090, Train Acc: 0.1052, Val Acc: 0.0000
# Epoch 4, Loss: 2.3088, Train Acc: 0.1028, Val Acc: 0.0000
# Epoch 5, Loss: 2.3089, Train Acc: 0.1045, Val Acc: 0.0000
# Epoch 6, Loss: 2.3086, Train Acc: 0.1038, Val Acc: 0.0000
# Epoch 7, Loss: 2.3086, Train Acc: 0.1049, Val Acc: 0.0000
# Epoch 8, Loss: 2.3086, Train Acc: 0.1057, Val Acc: 0.0000
# Epoch 9, Loss: 2.3090, Train Acc: 0.1040, Val Acc: 0.0000
# Epoch 10, Loss: 2.3090, Train Acc: 0.1044, Val Acc: 0.0000
# Epoch 11, Loss: 2.3090, Train Acc: 0.1038, Val Acc: 0.0000
# Epoch 12, Loss: 2.3089, Train Acc: 0.1037, Val Acc: 0.0000
# Epoch 13, Loss: 2.3089, Train Acc: 0.1033, Val Acc: 0.0000
# Epoch 14, Loss: 2.3088, Train Acc: 0.1037, Val Acc: 0.0000
# Epoch 15, Loss: 2.3086, Train Acc: 0.1045, Val Acc: 0.0000
# Epoch 16, Loss: 2.3088, Train Acc: 0.1043, Val Acc: 0.0000
# Epoch 17, Loss: 2.3088, Train Acc: 0.1051, Val Acc: 1.0000
# Epoch 18, Loss: 2.3086, Train Acc: 0.1040, Val Acc: 0.0000
# Epoch 19, Loss: 2.3089, Train Acc: 0.1030, Val Acc: 0.0000
# Epoch 20, Loss: 2.3088, Train Acc: 0.1049, Val Acc: 0.0000
# Epoch 21, Loss: 2.3089, Train Acc: 0.1036, Val Acc: 0.0000
# Epoch 22, Loss: 2.3089, Train Acc: 0.1024, Val Acc: 0.0000
# Epoch 23, Loss: 2.3085, Train Acc: 0.1052, Val Acc: 1.0000
# Epoch 24, Loss: 2.3089, Train Acc: 0.1047, Val Acc: 0.0000
# Epoch 25, Loss: 2.3088, Train Acc: 0.1043, Val Acc: 0.0000
# Epoch 26, Loss: 2.3088, Train Acc: 0.1027, Val Acc: 0.0000
# Epoch 27, Loss: 2.3083, Train Acc: 0.1050, Val Acc: 0.0000
# Epoch 28, Loss: 2.3087, Train Acc: 0.1036, Val Acc: 0.0000
# Epoch 29, Loss: 2.3090, Train Acc: 0.1033, Val Acc: 0.0000
# Epoch 30, Loss: 2.3089, Train Acc: 0.1053, Val Acc: 0.0000
# Epoch 31, Loss: 2.3089, Train Acc: 0.1044, Val Acc: 0.0000
# Epoch 32, Loss: 2.3091, Train Acc: 0.1033, Val Acc: 0.0000
# Epoch 33, Loss: 2.3090, Train Acc: 0.1029, Val Acc: 0.0000
# Epoch 34, Loss: 2.3088, Train Acc: 0.1041, Val Acc: 1.0000
# Epoch 35, Loss: 2.3082, Train Acc: 0.1057, Val Acc: 0.0000
# Epoch 36, Loss: 2.3089, Train Acc: 0.1031, Val Acc: 0.0000
# Epoch 37, Loss: 2.3089, Train Acc: 0.1040, Val Acc: 0.0000
# Epoch 38, Loss: 2.3087, Train Acc: 0.1038, Val Acc: 0.0000
# Epoch 39, Loss: 2.3091, Train Acc: 0.1028, Val Acc: 0.0000
# Epoch 40, Loss: 2.3082, Train Acc: 0.1066, Val Acc: 0.0000
# Epoch 41, Loss: 2.3087, Train Acc: 0.1051, Val Acc: 1.0000
# Epoch 42, Loss: 2.3088, Train Acc: 0.1054, Val Acc: 0.0000
# Epoch 43, Loss: 2.3089, Train Acc: 0.1042, Val Acc: 0.0000
# Epoch 44, Loss: 2.3089, Train Acc: 0.1028, Val Acc: 1.0000
# Epoch 45, Loss: 2.3092, Train Acc: 0.1019, Val Acc: 0.0000
# Epoch 46, Loss: 2.3086, Train Acc: 0.1051, Val Acc: 0.0000
# Epoch 47, Loss: 2.3088, Train Acc: 0.1047, Val Acc: 0.0000
# Epoch 48, Loss: 2.3086, Train Acc: 0.1035, Val Acc: 0.0000
# Epoch 49, Loss: 2.3088, Train Acc: 0.1035, Val Acc: 0.0000
# Epoch 50, Loss: 2.3087, Train Acc: 0.1035, Val Acc: 0.0000
# Epoch 51, Loss: 2.3088, Train Acc: 0.1050, Val Acc: 1.0000
# Epoch 52, Loss: 2.3087, Train Acc: 0.1042, Val Acc: 0.0000
# Epoch 53, Loss: 2.3087, Train Acc: 0.1020, Val Acc: 0.0000
# Epoch 54, Loss: 2.3092, Train Acc: 0.1032, Val Acc: 0.0000
# Epoch 55, Loss: 2.3091, Train Acc: 0.1025, Val Acc: 1.0000
# Epoch 56, Loss: 2.3092, Train Acc: 0.1027, Val Acc: 0.0000
# Epoch 57, Loss: 2.3091, Train Acc: 0.1044, Val Acc: 0.0000
# Epoch 58, Loss: 2.3085, Train Acc: 0.1017, Val Acc: 0.0000
# Epoch 59, Loss: 2.3087, Train Acc: 0.1043, Val Acc: 0.0000
# Epoch 60, Loss: 2.3087, Train Acc: 0.1047, Val Acc: 0.0000
# Epoch 61, Loss: 2.3089, Train Acc: 0.1024, Val Acc: 0.0000
# Epoch 62, Loss: 2.3085, Train Acc: 0.1054, Val Acc: 0.0000
# Epoch 63, Loss: 2.3089, Train Acc: 0.1055, Val Acc: 0.0000
# Epoch 64, Loss: 2.3087, Train Acc: 0.1049, Val Acc: 0.0000
# Epoch 65, Loss: 2.3088, Train Acc: 0.1047, Val Acc: 0.0000
# Epoch 66, Loss: 2.3088, Train Acc: 0.1038, Val Acc: 0.0000
# Epoch 67, Loss: 2.3087, Train Acc: 0.1041, Val Acc: 0.0000
# Epoch 68, Loss: 2.3083, Train Acc: 0.1062, Val Acc: 0.0000
# Epoch 69, Loss: 2.3090, Train Acc: 0.1022, Val Acc: 0.0000
# Epoch 70, Loss: 2.3087, Train Acc: 0.1040, Val Acc: 0.0000
# Epoch 71, Loss: 2.3087, Train Acc: 0.1032, Val Acc: 0.0000
# Epoch 72, Loss: 2.3086, Train Acc: 0.1056, Val Acc: 0.0000
# Epoch 73, Loss: 2.3086, Train Acc: 0.1048, Val Acc: 0.0000
# Epoch 74, Loss: 2.3087, Train Acc: 0.1036, Val Acc: 0.0000
# Epoch 75, Loss: 2.3086, Train Acc: 0.1036, Val Acc: 0.0000
# Epoch 76, Loss: 2.3089, Train Acc: 0.1040, Val Acc: 0.0000
# Epoch 77, Loss: 2.3091, Train Acc: 0.1028, Val Acc: 0.0000
# Epoch 78, Loss: 2.3089, Train Acc: 0.1034, Val Acc: 0.0000
# Epoch 79, Loss: 2.3086, Train Acc: 0.1068, Val Acc: 0.0000
# Epoch 80, Loss: 2.3087, Train Acc: 0.1036, Val Acc: 0.0000
# Epoch 81, Loss: 2.3090, Train Acc: 0.1040, Val Acc: 0.0000
# Epoch 82, Loss: 2.3084, Train Acc: 0.1049, Val Acc: 0.0000
# Epoch 83, Loss: 2.3087, Train Acc: 0.1040, Val Acc: 1.0000
# Epoch 84, Loss: 2.3088, Train Acc: 0.1045, Val Acc: 0.0000
# Epoch 85, Loss: 2.3086, Train Acc: 0.1050, Val Acc: 0.0000
# Epoch 86, Loss: 2.3089, Train Acc: 0.1043, Val Acc: 1.0000
# Epoch 87, Loss: 2.3087, Train Acc: 0.1053, Val Acc: 0.0000
# Epoch 88, Loss: 2.3088, Train Acc: 0.1055, Val Acc: 0.0000
# Epoch 89, Loss: 2.3087, Train Acc: 0.1042, Val Acc: 0.0000
# Epoch 90, Loss: 2.3093, Train Acc: 0.1008, Val Acc: 0.0000
# Epoch 91, Loss: 2.3087, Train Acc: 0.1047, Val Acc: 0.0000
# Epoch 92, Loss: 2.3086, Train Acc: 0.1045, Val Acc: 0.0000
# Epoch 93, Loss: 2.3092, Train Acc: 0.1030, Val Acc: 0.0000
# Epoch 94, Loss: 2.3086, Train Acc: 0.1030, Val Acc: 0.0000
# Epoch 95, Loss: 2.3091, Train Acc: 0.1024, Val Acc: 1.0000
# Epoch 96, Loss: 2.3085, Train Acc: 0.1047, Val Acc: 0.0000
# Epoch 97, Loss: 2.3089, Train Acc: 0.1029, Val Acc: 0.0000
# Epoch 98, Loss: 2.3086, Train Acc: 0.1030, Val Acc: 0.0000
# Epoch 99, Loss: 2.3083, Train Acc: 0.1029, Val Acc: 0.0000
# Epoch 100, Loss: 2.3088, Train Acc: 0.1039, Val Acc: 0.0000
# Test Accuracy: 0.1010
#
# Training with batch_size=10, epochs=10
# Epoch 1, Loss: 4.6099, Train Acc: 0.6942, Val Acc: 0.8000
# Epoch 2, Loss: 0.6792, Train Acc: 0.8213, Val Acc: 0.9000
# Epoch 3, Loss: 0.4554, Train Acc: 0.8913, Val Acc: 0.9000
# Epoch 4, Loss: 0.3996, Train Acc: 0.9055, Val Acc: 0.9000
# Epoch 5, Loss: 0.3704, Train Acc: 0.9102, Val Acc: 1.0000
# Epoch 6, Loss: 0.3832, Train Acc: 0.9107, Val Acc: 1.0000
# Epoch 7, Loss: 0.3923, Train Acc: 0.9070, Val Acc: 0.8000
# Epoch 8, Loss: 0.4492, Train Acc: 0.9007, Val Acc: 0.9000
# Epoch 9, Loss: 0.4074, Train Acc: 0.9041, Val Acc: 0.9000
# Epoch 10, Loss: 0.4101, Train Acc: 0.9018, Val Acc: 0.9000
# Test Accuracy: 0.9109
#
# Training with batch_size=10, epochs=50
# Epoch 1, Loss: 4.5477, Train Acc: 0.6817, Val Acc: 0.7000
# Epoch 2, Loss: 0.6042, Train Acc: 0.8623, Val Acc: 0.9000
# Epoch 3, Loss: 0.4529, Train Acc: 0.9067, Val Acc: 0.9000
# Epoch 4, Loss: 0.4394, Train Acc: 0.9106, Val Acc: 1.0000
# Epoch 5, Loss: 0.4076, Train Acc: 0.9195, Val Acc: 1.0000
# Epoch 6, Loss: 0.3982, Train Acc: 0.9224, Val Acc: 1.0000
# Epoch 7, Loss: 0.4139, Train Acc: 0.9172, Val Acc: 0.8000
# Epoch 8, Loss: 0.4134, Train Acc: 0.9180, Val Acc: 0.9000
# Epoch 9, Loss: 0.4079, Train Acc: 0.9200, Val Acc: 0.9000
# Epoch 10, Loss: 0.4081, Train Acc: 0.9204, Val Acc: 0.9000
# Epoch 11, Loss: 0.4136, Train Acc: 0.9202, Val Acc: 1.0000
# Epoch 12, Loss: 0.4452, Train Acc: 0.9163, Val Acc: 1.0000
# Epoch 13, Loss: 0.4201, Train Acc: 0.9206, Val Acc: 0.9000
# Epoch 14, Loss: 0.4195, Train Acc: 0.9178, Val Acc: 1.0000
# Epoch 15, Loss: 0.4198, Train Acc: 0.9105, Val Acc: 0.7000
# Epoch 16, Loss: 0.4483, Train Acc: 0.9132, Val Acc: 0.8000
# Epoch 17, Loss: 0.4464, Train Acc: 0.9137, Val Acc: 0.8000
# Epoch 18, Loss: 0.4664, Train Acc: 0.9149, Val Acc: 0.9000
# Epoch 19, Loss: 0.4822, Train Acc: 0.9024, Val Acc: 1.0000
# Epoch 20, Loss: 0.5194, Train Acc: 0.8945, Val Acc: 1.0000
# Epoch 21, Loss: 0.5525, Train Acc: 0.8844, Val Acc: 0.8000
# Epoch 22, Loss: 0.5335, Train Acc: 0.8869, Val Acc: 0.9000
# Epoch 23, Loss: 0.5288, Train Acc: 0.8861, Val Acc: 0.8000
# Epoch 24, Loss: 0.5684, Train Acc: 0.8781, Val Acc: 0.9000
# Epoch 25, Loss: 0.5234, Train Acc: 0.8728, Val Acc: 0.9000
# Epoch 26, Loss: 0.6461, Train Acc: 0.8567, Val Acc: 0.9000
# Epoch 27, Loss: 0.6511, Train Acc: 0.8590, Val Acc: 1.0000
# Epoch 28, Loss: 0.6867, Train Acc: 0.8492, Val Acc: 0.7000
# Epoch 29, Loss: 0.6899, Train Acc: 0.8544, Val Acc: 0.8000
# Epoch 30, Loss: 0.6905, Train Acc: 0.8454, Val Acc: 0.7000
# Epoch 31, Loss: 0.7204, Train Acc: 0.8511, Val Acc: 0.5000
# Epoch 32, Loss: 0.7178, Train Acc: 0.8490, Val Acc: 0.9000
# Epoch 33, Loss: 0.6444, Train Acc: 0.8513, Val Acc: 0.7000
# Epoch 34, Loss: 0.7158, Train Acc: 0.8447, Val Acc: 0.8000
# Epoch 35, Loss: 0.7169, Train Acc: 0.8293, Val Acc: 1.0000
# Epoch 36, Loss: 0.7581, Train Acc: 0.8144, Val Acc: 0.8000
# Epoch 37, Loss: 0.7223, Train Acc: 0.8368, Val Acc: 0.8000
# Epoch 38, Loss: 0.8135, Train Acc: 0.8104, Val Acc: 1.0000
# Epoch 39, Loss: 0.8397, Train Acc: 0.8099, Val Acc: 0.8000
# Epoch 40, Loss: 0.7665, Train Acc: 0.7817, Val Acc: 0.7000
# Epoch 41, Loss: 0.7997, Train Acc: 0.7976, Val Acc: 0.9000
# Epoch 42, Loss: 0.8188, Train Acc: 0.8056, Val Acc: 0.7000
# Epoch 43, Loss: 0.8166, Train Acc: 0.8009, Val Acc: 0.9000
# Epoch 44, Loss: 0.8137, Train Acc: 0.7861, Val Acc: 0.6000
# Epoch 45, Loss: 0.8378, Train Acc: 0.7865, Val Acc: 0.5000
# Epoch 46, Loss: 0.9130, Train Acc: 0.7608, Val Acc: 0.9000
# Epoch 47, Loss: 0.9252, Train Acc: 0.7499, Val Acc: 0.6000
# Epoch 48, Loss: 1.5471, Train Acc: 0.7510, Val Acc: 0.8000
# Epoch 49, Loss: 1.1320, Train Acc: 0.7367, Val Acc: 0.8000
# Epoch 50, Loss: 1.0740, Train Acc: 0.7199, Val Acc: 0.6000
# Test Accuracy: 0.5844
#
# Training with batch_size=10, epochs=100
# Epoch 1, Loss: 4.2964, Train Acc: 0.5958, Val Acc: 0.7000
# Epoch 2, Loss: 0.8263, Train Acc: 0.7597, Val Acc: 0.9000
# Epoch 3, Loss: 0.5274, Train Acc: 0.8684, Val Acc: 0.9000
# Epoch 4, Loss: 0.4699, Train Acc: 0.8920, Val Acc: 1.0000
# Epoch 5, Loss: 0.4078, Train Acc: 0.9117, Val Acc: 0.7000
# Epoch 6, Loss: 0.3896, Train Acc: 0.9169, Val Acc: 0.9000
# Epoch 7, Loss: 0.4226, Train Acc: 0.9104, Val Acc: 0.9000
# Epoch 8, Loss: 0.3948, Train Acc: 0.9175, Val Acc: 0.9000
# Epoch 9, Loss: 0.3872, Train Acc: 0.9189, Val Acc: 0.9000
# Epoch 10, Loss: 0.3818, Train Acc: 0.9236, Val Acc: 1.0000
# Epoch 11, Loss: 0.3984, Train Acc: 0.9173, Val Acc: 1.0000
# Epoch 12, Loss: 0.3816, Train Acc: 0.9222, Val Acc: 0.9000
# Epoch 13, Loss: 0.3785, Train Acc: 0.9216, Val Acc: 0.7000
# Epoch 14, Loss: 0.3927, Train Acc: 0.9157, Val Acc: 1.0000
# Epoch 15, Loss: 0.4371, Train Acc: 0.9154, Val Acc: 1.0000
# Epoch 16, Loss: 0.4180, Train Acc: 0.9110, Val Acc: 1.0000
# Epoch 17, Loss: 0.4223, Train Acc: 0.9126, Val Acc: 1.0000
# Epoch 18, Loss: 0.4801, Train Acc: 0.9003, Val Acc: 0.9000
# Epoch 19, Loss: 0.4361, Train Acc: 0.9013, Val Acc: 1.0000
# Epoch 20, Loss: 0.4766, Train Acc: 0.9052, Val Acc: 0.9000
# Epoch 21, Loss: 0.4822, Train Acc: 0.8975, Val Acc: 1.0000
# Epoch 22, Loss: 0.4517, Train Acc: 0.8971, Val Acc: 0.9000
# Epoch 23, Loss: 0.4792, Train Acc: 0.8963, Val Acc: 1.0000
# Epoch 24, Loss: 0.5161, Train Acc: 0.8935, Val Acc: 1.0000
# Epoch 25, Loss: 0.4956, Train Acc: 0.8935, Val Acc: 0.9000
# Epoch 26, Loss: 0.4931, Train Acc: 0.8935, Val Acc: 0.9000
# Epoch 27, Loss: 0.5135, Train Acc: 0.8914, Val Acc: 0.9000
# Epoch 28, Loss: 0.5063, Train Acc: 0.8923, Val Acc: 0.8000
# Epoch 29, Loss: 0.4794, Train Acc: 0.8936, Val Acc: 0.9000
# Epoch 30, Loss: 0.5500, Train Acc: 0.8730, Val Acc: 0.7000
# Epoch 31, Loss: 0.5231, Train Acc: 0.8821, Val Acc: 1.0000
# Epoch 32, Loss: 0.5079, Train Acc: 0.8951, Val Acc: 0.9000
# Epoch 33, Loss: 0.5646, Train Acc: 0.8866, Val Acc: 0.8000
# Epoch 34, Loss: 0.4795, Train Acc: 0.8889, Val Acc: 1.0000
# Epoch 35, Loss: 0.5802, Train Acc: 0.8828, Val Acc: 1.0000
# Epoch 36, Loss: 0.5984, Train Acc: 0.8822, Val Acc: 0.9000
# Epoch 37, Loss: 0.5737, Train Acc: 0.8682, Val Acc: 0.9000
# Epoch 38, Loss: 0.5735, Train Acc: 0.8679, Val Acc: 1.0000
# Epoch 39, Loss: 0.6006, Train Acc: 0.8567, Val Acc: 1.0000
# Epoch 40, Loss: 0.7586, Train Acc: 0.8485, Val Acc: 0.9000
# Epoch 41, Loss: 0.6279, Train Acc: 0.8754, Val Acc: 0.8000
# Epoch 42, Loss: 0.5694, Train Acc: 0.8667, Val Acc: 1.0000
# Epoch 43, Loss: 0.6719, Train Acc: 0.8516, Val Acc: 1.0000
# Epoch 44, Loss: 0.6843, Train Acc: 0.8417, Val Acc: 1.0000
# Epoch 45, Loss: 0.7434, Train Acc: 0.8314, Val Acc: 0.7000
# Epoch 46, Loss: 0.7510, Train Acc: 0.8291, Val Acc: 0.9000
# Epoch 47, Loss: 0.7345, Train Acc: 0.8225, Val Acc: 0.6000
# Epoch 48, Loss: 0.7959, Train Acc: 0.8173, Val Acc: 0.7000
# Epoch 49, Loss: 0.9701, Train Acc: 0.7802, Val Acc: 0.9000
# Epoch 50, Loss: 1.0412, Train Acc: 0.7482, Val Acc: 0.9000
# Epoch 51, Loss: 0.8588, Train Acc: 0.7517, Val Acc: 0.9000
# Epoch 52, Loss: 1.1728, Train Acc: 0.6786, Val Acc: 0.7000
# Epoch 53, Loss: 0.9798, Train Acc: 0.7070, Val Acc: 0.6000
# Epoch 54, Loss: 1.0945, Train Acc: 0.6990, Val Acc: 0.9000
# Epoch 55, Loss: 1.0471, Train Acc: 0.6731, Val Acc: 0.5000
# Epoch 56, Loss: 1.2228, Train Acc: 0.6672, Val Acc: 0.4000
# Epoch 57, Loss: 1.1000, Train Acc: 0.6663, Val Acc: 0.8000
# Epoch 58, Loss: 1.2109, Train Acc: 0.6402, Val Acc: 0.7000
# Epoch 59, Loss: 1.1905, Train Acc: 0.6571, Val Acc: 0.6000
# Epoch 60, Loss: 1.2646, Train Acc: 0.6280, Val Acc: 0.5000
# Epoch 61, Loss: 1.2849, Train Acc: 0.6413, Val Acc: 0.4000
# Epoch 62, Loss: 1.1785, Train Acc: 0.6322, Val Acc: 0.7000
# Epoch 63, Loss: 1.4586, Train Acc: 0.6253, Val Acc: 0.7000
# Epoch 64, Loss: 1.3384, Train Acc: 0.6292, Val Acc: 0.7000
# Epoch 65, Loss: 1.3591, Train Acc: 0.6182, Val Acc: 0.8000
# Epoch 66, Loss: 1.5593, Train Acc: 0.5849, Val Acc: 0.5000
# Epoch 67, Loss: 1.3688, Train Acc: 0.5312, Val Acc: 0.5000
# Epoch 68, Loss: 1.4494, Train Acc: 0.5623, Val Acc: 0.4000
# Epoch 69, Loss: 1.5481, Train Acc: 0.5922, Val Acc: 0.4000
# Epoch 70, Loss: 1.3972, Train Acc: 0.5654, Val Acc: 0.4000
# Epoch 71, Loss: 1.3810, Train Acc: 0.5754, Val Acc: 0.3000
# Epoch 72, Loss: 1.5019, Train Acc: 0.5728, Val Acc: 0.6000
# Epoch 73, Loss: 1.4803, Train Acc: 0.5249, Val Acc: 0.3000
# Epoch 74, Loss: 1.4711, Train Acc: 0.5675, Val Acc: 0.5000
# Epoch 75, Loss: 1.3858, Train Acc: 0.5958, Val Acc: 0.7000
# Epoch 76, Loss: 1.5600, Train Acc: 0.5776, Val Acc: 0.7000
# Epoch 77, Loss: 1.5299, Train Acc: 0.6012, Val Acc: 0.7000
# Epoch 78, Loss: 1.5373, Train Acc: 0.5847, Val Acc: 0.6000
# Epoch 79, Loss: 1.3557, Train Acc: 0.5565, Val Acc: 0.5000
# Epoch 80, Loss: 1.4688, Train Acc: 0.5532, Val Acc: 0.8000
# Epoch 81, Loss: 1.6252, Train Acc: 0.5337, Val Acc: 0.7000
# Epoch 82, Loss: 2.0449, Train Acc: 0.5454, Val Acc: 0.5000
# Epoch 83, Loss: 1.5566, Train Acc: 0.5613, Val Acc: 0.4000
# Epoch 84, Loss: 1.5145, Train Acc: 0.5430, Val Acc: 0.5000
# Epoch 85, Loss: 2.1958, Train Acc: 0.5648, Val Acc: 0.8000
# Epoch 86, Loss: 1.3936, Train Acc: 0.5676, Val Acc: 0.3000
# Epoch 87, Loss: 1.4612, Train Acc: 0.5141, Val Acc: 0.4000
# Epoch 88, Loss: 2.1623, Train Acc: 0.5320, Val Acc: 0.7000
# Epoch 89, Loss: 1.4167, Train Acc: 0.5364, Val Acc: 0.7000
# Epoch 90, Loss: 1.8400, Train Acc: 0.5448, Val Acc: 0.4000
# Epoch 91, Loss: 1.3922, Train Acc: 0.5237, Val Acc: 0.6000
# Epoch 92, Loss: 1.7054, Train Acc: 0.5188, Val Acc: 0.4000
# Epoch 93, Loss: 1.3500, Train Acc: 0.5278, Val Acc: 0.2000
# Epoch 94, Loss: 1.5734, Train Acc: 0.5083, Val Acc: 0.5000
# Epoch 95, Loss: 1.5041, Train Acc: 0.5147, Val Acc: 0.5000
# Epoch 96, Loss: 1.8857, Train Acc: 0.5146, Val Acc: 0.1000
# Epoch 97, Loss: 1.6128, Train Acc: 0.5136, Val Acc: 0.5000
# Epoch 98, Loss: 1.6286, Train Acc: 0.4911, Val Acc: 0.4000
# Epoch 99, Loss: 1.7514, Train Acc: 0.4703, Val Acc: 0.6000
# Epoch 100, Loss: 1.5657, Train Acc: 0.5290, Val Acc: 0.6000
# Test Accuracy: 0.4731
#
# Training with batch_size=100, epochs=10
# Epoch 1, Loss: 10.7389, Train Acc: 0.6684, Val Acc: 0.6600
# Epoch 2, Loss: 0.9129, Train Acc: 0.7543, Val Acc: 0.7900
# Epoch 3, Loss: 0.6141, Train Acc: 0.8245, Val Acc: 0.8200
# Epoch 4, Loss: 0.4844, Train Acc: 0.8608, Val Acc: 0.8800
# Epoch 5, Loss: 0.3989, Train Acc: 0.8849, Val Acc: 0.9000
# Epoch 6, Loss: 0.3378, Train Acc: 0.9044, Val Acc: 0.8700
# Epoch 7, Loss: 0.2943, Train Acc: 0.9166, Val Acc: 0.9600
# Epoch 8, Loss: 0.2609, Train Acc: 0.9269, Val Acc: 0.9300
# Epoch 9, Loss: 0.2347, Train Acc: 0.9347, Val Acc: 0.9400
# Epoch 10, Loss: 0.2143, Train Acc: 0.9421, Val Acc: 0.9800
# Test Accuracy: 0.9357
#
# Training with batch_size=100, epochs=50
# Epoch 1, Loss: 17.0539, Train Acc: 0.7660, Val Acc: 0.6600
# Epoch 2, Loss: 1.1041, Train Acc: 0.7318, Val Acc: 0.7800
# Epoch 3, Loss: 0.6867, Train Acc: 0.8143, Val Acc: 0.8500
# Epoch 4, Loss: 0.5012, Train Acc: 0.8602, Val Acc: 0.8100
# Epoch 5, Loss: 0.4000, Train Acc: 0.8869, Val Acc: 0.8500
# Epoch 6, Loss: 0.3395, Train Acc: 0.9053, Val Acc: 0.9100
# Epoch 7, Loss: 0.3065, Train Acc: 0.9140, Val Acc: 0.9500
# Epoch 8, Loss: 0.2692, Train Acc: 0.9236, Val Acc: 0.9900
# Epoch 9, Loss: 0.2447, Train Acc: 0.9318, Val Acc: 0.9500
# Epoch 10, Loss: 0.2143, Train Acc: 0.9399, Val Acc: 0.9800
# Epoch 11, Loss: 0.2065, Train Acc: 0.9446, Val Acc: 0.9700
# Epoch 12, Loss: 0.1840, Train Acc: 0.9494, Val Acc: 0.9500
# Epoch 13, Loss: 0.1672, Train Acc: 0.9547, Val Acc: 0.9400
# Epoch 14, Loss: 0.1548, Train Acc: 0.9577, Val Acc: 0.9800
# Epoch 15, Loss: 0.1399, Train Acc: 0.9628, Val Acc: 0.9600
# Epoch 16, Loss: 0.1274, Train Acc: 0.9654, Val Acc: 0.9700
# Epoch 17, Loss: 0.1225, Train Acc: 0.9675, Val Acc: 0.9900
# Epoch 18, Loss: 0.1091, Train Acc: 0.9703, Val Acc: 1.0000
# Epoch 19, Loss: 0.1259, Train Acc: 0.9672, Val Acc: 0.9800
# Epoch 20, Loss: 0.1068, Train Acc: 0.9725, Val Acc: 0.9900
# Epoch 21, Loss: 0.0989, Train Acc: 0.9744, Val Acc: 0.9800
# Epoch 22, Loss: 0.0906, Train Acc: 0.9767, Val Acc: 0.9800
# Epoch 23, Loss: 0.0845, Train Acc: 0.9778, Val Acc: 1.0000
# Epoch 24, Loss: 0.0902, Train Acc: 0.9773, Val Acc: 1.0000
# Epoch 25, Loss: 0.0825, Train Acc: 0.9795, Val Acc: 0.9900
# Epoch 26, Loss: 0.0728, Train Acc: 0.9808, Val Acc: 0.9900
# Epoch 27, Loss: 0.0882, Train Acc: 0.9778, Val Acc: 0.9800
# Epoch 28, Loss: 0.0724, Train Acc: 0.9813, Val Acc: 0.9900
# Epoch 29, Loss: 0.0748, Train Acc: 0.9817, Val Acc: 1.0000
# Epoch 30, Loss: 0.0787, Train Acc: 0.9812, Val Acc: 0.9700
# Epoch 31, Loss: 0.0712, Train Acc: 0.9826, Val Acc: 0.9700
# Epoch 32, Loss: 0.0673, Train Acc: 0.9837, Val Acc: 0.9900
# Epoch 33, Loss: 0.0736, Train Acc: 0.9821, Val Acc: 1.0000
# Epoch 34, Loss: 0.0579, Train Acc: 0.9848, Val Acc: 0.9700
# Epoch 35, Loss: 0.0681, Train Acc: 0.9833, Val Acc: 0.9900
# Epoch 36, Loss: 0.0606, Train Acc: 0.9851, Val Acc: 0.9800
# Epoch 37, Loss: 0.0662, Train Acc: 0.9846, Val Acc: 0.9900
# Epoch 38, Loss: 0.0601, Train Acc: 0.9849, Val Acc: 1.0000
# Epoch 39, Loss: 0.0591, Train Acc: 0.9855, Val Acc: 0.9900
# Epoch 40, Loss: 0.0646, Train Acc: 0.9851, Val Acc: 1.0000
# Epoch 41, Loss: 0.0470, Train Acc: 0.9880, Val Acc: 0.9800
# Epoch 42, Loss: 0.0596, Train Acc: 0.9861, Val Acc: 0.9900
# Epoch 43, Loss: 0.0567, Train Acc: 0.9867, Val Acc: 1.0000
# Epoch 44, Loss: 0.0652, Train Acc: 0.9856, Val Acc: 0.9700
# Epoch 45, Loss: 0.0525, Train Acc: 0.9873, Val Acc: 0.9700
# Epoch 46, Loss: 0.0507, Train Acc: 0.9881, Val Acc: 0.9800
# Epoch 47, Loss: 0.0467, Train Acc: 0.9889, Val Acc: 1.0000
# Epoch 48, Loss: 0.0676, Train Acc: 0.9851, Val Acc: 0.9700
# Epoch 49, Loss: 0.0616, Train Acc: 0.9870, Val Acc: 0.9900
# Epoch 50, Loss: 0.0570, Train Acc: 0.9870, Val Acc: 0.9800
# Test Accuracy: 0.9656
#
# Training with batch_size=100, epochs=100
# Epoch 1, Loss: 15.0868, Train Acc: 0.8006, Val Acc: 0.8300
# Epoch 2, Loss: 1.0384, Train Acc: 0.8162, Val Acc: 0.9000
# Epoch 3, Loss: 0.5107, Train Acc: 0.8673, Val Acc: 0.9100
# Epoch 4, Loss: 0.3782, Train Acc: 0.8962, Val Acc: 0.8800
# Epoch 5, Loss: 0.3062, Train Acc: 0.9130, Val Acc: 0.9400
# Epoch 6, Loss: 0.2607, Train Acc: 0.9262, Val Acc: 0.9400
# Epoch 7, Loss: 0.2282, Train Acc: 0.9338, Val Acc: 0.9800
# Epoch 8, Loss: 0.2160, Train Acc: 0.9396, Val Acc: 0.9300
# Epoch 9, Loss: 0.1967, Train Acc: 0.9452, Val Acc: 0.9200
# Epoch 10, Loss: 0.1765, Train Acc: 0.9495, Val Acc: 0.9600
# Epoch 11, Loss: 0.1576, Train Acc: 0.9550, Val Acc: 0.9800
# Epoch 12, Loss: 0.1467, Train Acc: 0.9592, Val Acc: 0.9300
# Epoch 13, Loss: 0.1478, Train Acc: 0.9593, Val Acc: 0.9700
# Epoch 14, Loss: 0.1331, Train Acc: 0.9637, Val Acc: 0.9600
# Epoch 15, Loss: 0.1228, Train Acc: 0.9668, Val Acc: 0.9700
# Epoch 16, Loss: 0.1180, Train Acc: 0.9683, Val Acc: 0.9800
# Epoch 17, Loss: 0.1137, Train Acc: 0.9710, Val Acc: 0.9900
# Epoch 18, Loss: 0.0983, Train Acc: 0.9730, Val Acc: 1.0000
# Epoch 19, Loss: 0.0922, Train Acc: 0.9757, Val Acc: 0.9900
# Epoch 20, Loss: 0.0874, Train Acc: 0.9764, Val Acc: 1.0000
# Epoch 21, Loss: 0.0857, Train Acc: 0.9768, Val Acc: 0.9800
# Epoch 22, Loss: 0.0856, Train Acc: 0.9777, Val Acc: 1.0000
# Epoch 23, Loss: 0.0733, Train Acc: 0.9805, Val Acc: 0.9900
# Epoch 24, Loss: 0.0721, Train Acc: 0.9811, Val Acc: 1.0000
# Epoch 25, Loss: 0.0705, Train Acc: 0.9821, Val Acc: 1.0000
# Epoch 26, Loss: 0.0703, Train Acc: 0.9821, Val Acc: 0.9700
# Epoch 27, Loss: 0.0664, Train Acc: 0.9831, Val Acc: 0.9900
# Epoch 28, Loss: 0.0697, Train Acc: 0.9819, Val Acc: 0.9800
# Epoch 29, Loss: 0.0615, Train Acc: 0.9833, Val Acc: 0.9900
# Epoch 30, Loss: 0.0657, Train Acc: 0.9835, Val Acc: 1.0000
# Epoch 31, Loss: 0.0610, Train Acc: 0.9847, Val Acc: 0.9900
# Epoch 32, Loss: 0.0570, Train Acc: 0.9851, Val Acc: 1.0000
# Epoch 33, Loss: 0.0628, Train Acc: 0.9845, Val Acc: 0.9700
# Epoch 34, Loss: 0.0548, Train Acc: 0.9859, Val Acc: 1.0000
# Epoch 35, Loss: 0.0587, Train Acc: 0.9859, Val Acc: 1.0000
# Epoch 36, Loss: 0.0565, Train Acc: 0.9860, Val Acc: 1.0000
# Epoch 37, Loss: 0.0660, Train Acc: 0.9848, Val Acc: 1.0000
# Epoch 38, Loss: 0.0492, Train Acc: 0.9870, Val Acc: 0.9900
# Epoch 39, Loss: 0.0691, Train Acc: 0.9850, Val Acc: 1.0000
# Epoch 40, Loss: 0.0557, Train Acc: 0.9869, Val Acc: 0.9900
# Epoch 41, Loss: 0.0448, Train Acc: 0.9890, Val Acc: 0.9900
# Epoch 42, Loss: 0.0500, Train Acc: 0.9874, Val Acc: 1.0000
# Epoch 43, Loss: 0.0504, Train Acc: 0.9879, Val Acc: 0.9800
# Epoch 44, Loss: 0.0503, Train Acc: 0.9882, Val Acc: 1.0000
# Epoch 45, Loss: 0.0489, Train Acc: 0.9887, Val Acc: 1.0000
# Epoch 46, Loss: 0.0524, Train Acc: 0.9872, Val Acc: 1.0000
# Epoch 47, Loss: 0.0721, Train Acc: 0.9853, Val Acc: 0.9900
# Epoch 48, Loss: 0.0537, Train Acc: 0.9878, Val Acc: 0.9800
# Epoch 49, Loss: 0.0501, Train Acc: 0.9884, Val Acc: 1.0000
# Epoch 50, Loss: 0.0478, Train Acc: 0.9892, Val Acc: 0.9500
# Epoch 51, Loss: 0.0461, Train Acc: 0.9893, Val Acc: 0.9900
# Epoch 52, Loss: 0.0492, Train Acc: 0.9897, Val Acc: 1.0000
# Epoch 53, Loss: 0.0585, Train Acc: 0.9878, Val Acc: 0.9900
# Epoch 54, Loss: 0.0517, Train Acc: 0.9887, Val Acc: 1.0000
# Epoch 55, Loss: 0.0442, Train Acc: 0.9894, Val Acc: 1.0000
# Epoch 56, Loss: 0.0526, Train Acc: 0.9883, Val Acc: 1.0000
# Epoch 57, Loss: 0.0414, Train Acc: 0.9903, Val Acc: 1.0000
# Epoch 58, Loss: 0.0420, Train Acc: 0.9901, Val Acc: 1.0000
# Epoch 59, Loss: 0.0464, Train Acc: 0.9897, Val Acc: 0.9700
# Epoch 60, Loss: 0.0444, Train Acc: 0.9892, Val Acc: 0.9900
# Epoch 61, Loss: 0.0657, Train Acc: 0.9875, Val Acc: 1.0000
# Epoch 62, Loss: 0.0479, Train Acc: 0.9891, Val Acc: 0.9900
# Epoch 63, Loss: 0.0404, Train Acc: 0.9908, Val Acc: 1.0000
# Epoch 64, Loss: 0.0442, Train Acc: 0.9899, Val Acc: 1.0000
# Epoch 65, Loss: 0.0414, Train Acc: 0.9910, Val Acc: 0.9800
# Epoch 66, Loss: 0.0533, Train Acc: 0.9897, Val Acc: 0.9900
# Epoch 67, Loss: 0.0545, Train Acc: 0.9897, Val Acc: 0.9900
# Epoch 68, Loss: 0.0429, Train Acc: 0.9904, Val Acc: 0.9900
# Epoch 69, Loss: 0.0608, Train Acc: 0.9872, Val Acc: 0.9900
# Epoch 70, Loss: 0.0443, Train Acc: 0.9905, Val Acc: 0.9900
# Epoch 71, Loss: 0.0420, Train Acc: 0.9911, Val Acc: 1.0000
# Epoch 72, Loss: 0.0445, Train Acc: 0.9907, Val Acc: 1.0000
# Epoch 73, Loss: 0.0440, Train Acc: 0.9909, Val Acc: 1.0000
# Epoch 74, Loss: 0.0384, Train Acc: 0.9913, Val Acc: 1.0000
# Epoch 75, Loss: 0.0388, Train Acc: 0.9913, Val Acc: 1.0000
# Epoch 76, Loss: 0.0413, Train Acc: 0.9907, Val Acc: 1.0000
# Epoch 77, Loss: 0.0502, Train Acc: 0.9890, Val Acc: 1.0000
# Epoch 78, Loss: 0.0549, Train Acc: 0.9898, Val Acc: 0.9900
# Epoch 79, Loss: 0.0390, Train Acc: 0.9914, Val Acc: 0.9700
# Epoch 80, Loss: 0.0450, Train Acc: 0.9907, Val Acc: 1.0000
# Epoch 81, Loss: 0.0460, Train Acc: 0.9909, Val Acc: 1.0000
# Epoch 82, Loss: 0.0369, Train Acc: 0.9922, Val Acc: 1.0000
# Epoch 83, Loss: 0.0416, Train Acc: 0.9913, Val Acc: 1.0000
# Epoch 84, Loss: 0.0425, Train Acc: 0.9914, Val Acc: 1.0000
# Epoch 85, Loss: 0.0424, Train Acc: 0.9910, Val Acc: 0.9900
# Epoch 86, Loss: 0.0360, Train Acc: 0.9925, Val Acc: 0.9900
# Epoch 87, Loss: 0.0392, Train Acc: 0.9920, Val Acc: 1.0000
# Epoch 88, Loss: 0.0406, Train Acc: 0.9902, Val Acc: 1.0000
# Epoch 89, Loss: 0.0549, Train Acc: 0.9897, Val Acc: 1.0000
# Epoch 90, Loss: 0.0437, Train Acc: 0.9911, Val Acc: 1.0000
# Epoch 91, Loss: 0.0407, Train Acc: 0.9915, Val Acc: 0.9900
# Epoch 92, Loss: 0.0401, Train Acc: 0.9922, Val Acc: 1.0000
# Epoch 93, Loss: 0.0491, Train Acc: 0.9907, Val Acc: 0.9800
# Epoch 94, Loss: 0.0482, Train Acc: 0.9904, Val Acc: 1.0000
# Epoch 95, Loss: 0.0406, Train Acc: 0.9915, Val Acc: 0.9900
# Epoch 96, Loss: 0.0454, Train Acc: 0.9908, Val Acc: 1.0000
# Epoch 97, Loss: 0.0424, Train Acc: 0.9910, Val Acc: 0.9900
# Epoch 98, Loss: 0.0400, Train Acc: 0.9913, Val Acc: 1.0000
# Epoch 99, Loss: 0.0483, Train Acc: 0.9903, Val Acc: 1.0000
# Epoch 100, Loss: 0.0439, Train Acc: 0.9907, Val Acc: 1.0000
# Test Accuracy: 0.9652
#
#  All Results Saved in training_results.xlsx
