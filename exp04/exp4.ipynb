# %%
import tensorflow.compat.v1 as tf
import tensorflow_datasets as tfds
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import time
from sklearn.metrics import confusion_matrix
from openpyxl import Workbook
tf.disable_v2_behavior()

mnist = tfds.load('mnist', split=['train', 'test'], as_supervised=True)
train_data, test_data = mnist

def preprocess(images, labels):
    images = tf.cast(images, tf.float32) / 255.0  # Normalize
    images = tf.reshape(images, [784])  # Flatten
    labels = tf.one_hot(labels, depth=10)  # One-hot encode
    return images, labels

batch_size_list = [1,10, 100]
epochs_list = [10, 50,100]

def train_and_evaluate(batch_size, epochs):
    print(f"\nTraining with batch_size={batch_size}, epochs={epochs}")

    train_dataset = train_data.map(preprocess).batch(batch_size)
    test_dataset = test_data.map(preprocess).batch(batch_size)

    X = tf.placeholder(tf.float32, [None, 784])
    Y = tf.placeholder(tf.float32, [None, 10])

    weights = {
        'h1': tf.Variable(tf.random_normal([784, 128])),
        'h2': tf.Variable(tf.random_normal([128, 64])),
        'out': tf.Variable(tf.random_normal([64, 10]))
    }
    biases = {
        'b1': tf.Variable(tf.random_normal([128])),
        'b2': tf.Variable(tf.random_normal([64])),
        'out': tf.Variable(tf.random_normal([10]))
    }

    def neural_network(x):
        layer1 = tf.nn.relu(tf.add(tf.matmul(x, weights['h1']), biases['b1']))
        layer2 = tf.nn.relu(tf.add(tf.matmul(layer1, weights['h2']), biases['b2']))
        return tf.add(tf.matmul(layer2, weights['out']), biases['out'])

    logits = neural_network(X)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=Y))
    optimizer = tf.train.AdamOptimizer(learning_rate=0.01).minimize(loss)

    predictions = tf.nn.softmax(logits)
    correct_pred = tf.equal(tf.argmax(predictions, 1), tf.argmax(Y, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

    loss_curve, acc_curve, val_acc_curve = [], [], []
    start_time = time.time()

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())

        for epoch in range(epochs):
            avg_loss = 0
            total_batches = 0
            iterator = tf.compat.v1.data.make_one_shot_iterator(train_dataset)
            next_batch = iterator.get_next()

            while True:
                try:
                    batch_x, batch_y = sess.run(next_batch)
                    _, c = sess.run([optimizer, loss], feed_dict={X: batch_x, Y: batch_y})
                    avg_loss += c
                    total_batches += 1
                except tf.errors.OutOfRangeError:
                    break  

            avg_loss /= total_batches
            train_acc = sess.run(accuracy, feed_dict={X: batch_x, Y: batch_y})
            val_acc = sess.run(accuracy, feed_dict={X: batch_x, Y: batch_y})

            loss_curve.append(avg_loss)
            acc_curve.append(train_acc)
            val_acc_curve.append(val_acc)

            print(f"Epoch {epoch+1}, Loss: {avg_loss:.4f}, Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}")

        end_time = time.time()
        execution_time = end_time - start_time

        test_acc = []
        y_true, y_pred = [], []
        iterator = tf.compat.v1.data.make_one_shot_iterator(test_dataset)
        next_batch = iterator.get_next()

        while True:
            try:
                batch_x, batch_y = sess.run(next_batch)
                acc, preds = sess.run([accuracy, predictions], feed_dict={X: batch_x, Y: batch_y})
                test_acc.append(acc)
                y_pred.extend(np.argmax(preds, axis=1))
                y_true.extend(np.argmax(batch_y, axis=1))
            except tf.errors.OutOfRangeError:
                break

        final_test_acc = np.mean(test_acc)
        print(f"Test Accuracy: {final_test_acc:.4f}")

        conf_matrix = confusion_matrix(y_true, y_pred)
        plt.figure(figsize=(8, 6))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title(f"Confusion Matrix (Batch={batch_size}, Epochs={epochs})")
        cm_filename = f"confusion_matrix_batch{batch_size}_epochs{epochs}.png"
        plt.savefig(cm_filename)
        plt.close()

        plt.figure(figsize=(12, 4))

        plt.subplot(1, 2, 1)
        plt.plot(loss_curve, label='Train Loss')
        plt.xlabel("Epochs")
        plt.ylabel("Loss")
        plt.legend()
        plt.title("Loss Curve")

        plt.subplot(1, 2, 2)
        plt.plot(acc_curve, label='Train Accuracy')
        plt.plot(val_acc_curve, label='Val Accuracy')
        plt.xlabel("Epochs")
        plt.ylabel("Accuracy")
        plt.legend()
        plt.title("Accuracy Curve")

        curve_filename = f"curves_batch{batch_size}_epochs{epochs}.png"
        plt.savefig(curve_filename)
        plt.close()

    return batch_size, epochs, execution_time, final_test_acc, cm_filename, curve_filename

results = []
for batch_size in batch_size_list:
    for epochs in epochs_list:
        res = train_and_evaluate(batch_size, epochs)
        results.append(res)

df = pd.DataFrame(results, columns=['Batch Size', 'Epochs', 'Execution Time (s)', 'Test Accuracy', 'Confusion Matrix Image', 'Loss/Accuracy Curves'])
df.to_excel("training_results.xlsx", index=False)

print("\n All Results Saved in training_results.xlsx")
# Out:
# WARNING:tensorflow:From C:\Users\91637\AppData\Local\Temp\ipykernel_21276\1538282329.py:10: The name tf.disable_v2_behavior is deprecated. Please use tf.compat.v1.disable_v2_behavior instead.
#
# WARNING:tensorflow:From c:\Python312\Lib\site-packages\tensorflow\python\compat\v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:absl:Variant folder C:\Users\91637\tensorflow_datasets\mnist\3.0.1 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to C:\Users\91637\tensorflow_datasets\mnist\3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling C:\Users\91637\tensorflow_datasets\mnist\incomplete.ZEYWRG_3.0.1\mnist-train.tfrecord*...:   0%|    …
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling C:\Users\91637\tensorflow_datasets\mnist\incomplete.ZEYWRG_3.0.1\mnist-test.tfrecord*...:   0%|     …
# Dataset mnist downloaded and prepared to C:\Users\91637\tensorflow_datasets\mnist\3.0.1. Subsequent calls will reuse this data.
#
# Training with batch_size=1, epochs=10
# WARNING:tensorflow:From C:\Users\91637\AppData\Local\Temp\ipykernel_21276\1538282329.py:51: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# WARNING:tensorflow:From C:\Users\91637\AppData\Local\Temp\ipykernel_21276\1538282329.py:51: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# WARNING:tensorflow:From C:\Users\91637\AppData\Local\Temp\ipykernel_21276\1538282329.py:66: The name tf.data.make_one_shot_iterator is deprecated. Please use tf.compat.v1.data.make_one_shot_iterator instead.
# WARNING:tensorflow:From C:\Users\91637\AppData\Local\Temp\ipykernel_21276\1538282329.py:66: The name tf.data.make_one_shot_iterator is deprecated. Please use tf.compat.v1.data.make_one_shot_iterator instead.
# Epoch 1, Loss: 3.6490, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 2, Loss: 2.2680, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 3, Loss: 2.3053, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 4, Loss: 2.3049, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 5, Loss: 2.4221, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 6, Loss: 2.3258, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 7, Loss: 2.2418, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 8, Loss: 2.3235, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 9, Loss: 2.4117, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 10, Loss: 2.3312, Train Acc: 0.0000, Val Acc: 0.0000
# Test Accuracy: 0.1390
#
# Training with batch_size=1, epochs=50
# Epoch 1, Loss: 3.8429, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 2, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 3, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 4, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 5, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 6, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 7, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 8, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 9, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 10, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 11, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 12, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 13, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 14, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 15, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 16, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 17, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 18, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 19, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 20, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 21, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 22, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 23, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 24, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 25, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 26, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 27, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 28, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 29, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 30, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 31, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 32, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 33, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 34, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 35, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 36, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 37, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 38, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 39, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 40, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 41, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 42, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 43, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 44, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 45, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 46, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 47, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 48, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 49, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 50, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Test Accuracy: 0.1135
#
# Training with batch_size=1, epochs=100
# Epoch 1, Loss: 3.4428, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 2, Loss: 2.2608, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 3, Loss: 2.1741, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 4, Loss: 2.1646, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 5, Loss: 2.2504, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 6, Loss: 2.1841, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 7, Loss: 2.2313, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 8, Loss: 2.2050, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 9, Loss: 2.3201, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch
Train Acc: 0.5000, Val Acc: 0.5000
# Epoch 88, Loss: 1.7108, Train Acc: 0.7000, Val Acc: 0.7000
# Epoch 89, Loss: 1.4907, Train Acc: 0.7000, Val Acc: 0.7000
# Epoch 90, Loss: 2.1648, Train Acc: 0.6000, Val Acc: 0.6000
# Epoch 91, Loss: 1.5335, Train Acc: 0.4000, Val Acc: 0.4000
# Epoch 92, Loss: 1.3875, Train Acc: 0.5000, Val Acc: 0.5000
# Epoch 93, Loss: 1.4037, Train Acc: 0.4000, Val Acc: 0.4000
# Epoch 94, Loss: 2.1382, Train Acc: 0.4000, Val Acc: 0.4000
# Epoch 95, Loss: 1.7096, Train Acc: 0.5000, Val Acc: 0.5000
# Epoch 96, Loss: 1.4207, Train Acc: 0.6000, Val Acc: 0.6000
# Epoch 97, Loss: 2.1076, Train Acc: 0.6000, Val Acc: 0.6000
# Epoch 98, Loss: 1.7475, Train Acc: 0.7000, Val Acc: 0.7000
# Epoch 99, Loss: 1.5399, Train Acc: 0.5000, Val Acc: 0.5000
# Epoch 100, Loss: 1.4439, Train Acc: 0.7000, Val Acc: 0.7000
# Test Accuracy: 0.4980
#
# Training with batch_size=100, epochs=10
# Epoch 1, Loss: 13.1091, Train Acc: 0.7300, Val Acc: 0.7300
# Epoch 2, Loss: 0.8714, Train Acc: 0.8200, Val Acc: 0.8200
# Epoch 3, Loss: 0.5731, Train Acc: 0.8700, Val Acc: 0.8700
# Epoch 4, Loss: 0.4361, Train Acc: 0.9300, Val Acc: 0.9300
# Epoch 5, Loss: 0.3559, Train Acc: 0.9500, Val Acc: 0.9500
# Epoch 6, Loss: 0.3137, Train Acc: 0.9600, Val Acc: 0.9600
# Epoch 7, Loss: 0.2655, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 8, Loss: 0.2543, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 9, Loss: 0.2373, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 10, Loss: 0.2084, Train Acc: 0.9900, Val Acc: 0.9900
# Test Accuracy: 0.9353
#
# Training with batch_size=100, epochs=50
# Epoch 1, Loss: 14.6112, Train Acc: 0.7600, Val Acc: 0.7600
# Epoch 2, Loss: 1.1047, Train Acc: 0.8200, Val Acc: 0.8200
# Epoch 3, Loss: 0.6880, Train Acc: 0.8700, Val Acc: 0.8700
# Epoch 4, Loss: 0.5077, Train Acc: 0.9300, Val Acc: 0.9300
# Epoch 5, Loss: 0.4014, Train Acc: 0.9400, Val Acc: 0.9400
# Epoch 6, Loss: 0.3307, Train Acc: 0.9600, Val Acc: 0.9600
# Epoch 7, Loss: 0.2705, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 8, Loss: 0.2347, Train Acc: 0.9500, Val Acc: 0.9500
# Epoch 9, Loss: 0.2108, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 10, Loss: 0.2059, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 11, Loss: 0.1729, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 12, Loss: 0.1709, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 13, Loss: 0.1540, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 14, Loss: 0.1417, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 15, Loss: 0.1352, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 16, Loss: 0.1266, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 17, Loss: 0.1129, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 18, Loss: 0.1160, Train Acc: 0.9700, Val Acc: 0.9700
# Epoch 19, Loss: 0.1042, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 20, Loss: 0.0934, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 21, Loss: 0.0968, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 22, Loss: 0.0894, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 23, Loss: 0.0889, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 24, Loss: 0.0964, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 25, Loss: 0.0870, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 26, Loss: 0.0883, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 27, Loss: 0.0744, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 28, Loss: 0.0738, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 29, Loss: 0.0716, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 30, Loss: 0.0661, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 31, Loss: 0.0716, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 32, Loss: 0.0705, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 33, Loss: 0.0679, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 34, Loss: 0.0565, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 35, Loss: 0.0598, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 36, Loss: 0.0567, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 37, Loss: 0.0696, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 38, Loss: 0.0707, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 39, Loss: 0.0729, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 40, Loss: 0.0582, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 41, Loss: 0.0465, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 42, Loss: 0.0642, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 43, Loss: 0.0558, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 44, Loss: 0.0584, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 45, Loss: 0.0625, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 46, Loss: 0.0482, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 47, Loss: 0.0509, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 48, Loss: 0.0475, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 49, Loss: 0.0655, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 50, Loss: 0.0497, Train Acc: 1.0000, Val Acc: 1.0000
# Test Accuracy: 0.9700
#
# Training with batch_size=100, epochs=100
# Epoch 1, Loss: 10.6509, Train Acc: 0.7000, Val Acc: 0.7000
# Epoch